# %%
import pandas as pd

# 파일 경로 지정
basic_path = "crawling_results/military_jobs_basic_20250425_162549.csv"
detail_path = "crawling_results/military_jobs_detail_20250425_162549.csv"

# CSV 파일 불러오기
basic_df = pd.read_csv(basic_path)
detail_df = pd.read_csv(detail_path)

# %%
# 컬럼명 확인
print("📌 Basic 컬럼들:", basic_df.columns.tolist())
print("📌 Detail 컬럼들:", detail_df.columns.tolist())

# 각 데이터프레임의 상위 5개 행 미리보기
display(basic_df.head())
display(detail_df.head())

# 데이터 크기 확인
print("기본정보 데이터 개수:", basic_df.shape)
print("상세정보 데이터 개수:", detail_df.shape)
# Out:
# 📌 Basic 컬럼들: ['번호', '채용제목', '업체명', '마감일', '작성일', '조회수', '상세정보_URL']
# 📌 Detail 컬럼들: ['상세정보_URL', '업체명', '업종', '주소', '홈페이지', '요원형태', '자격요원', '최종학력', '담당업무', '근무형태', '특근·잔업', '수습기간', '퇴직금지급', '현역배정인원', '보충역배정인원', '모집인원', '외국어', '복리후생', '비고']
#    번호                                               채용제목                업체명  \
# 0   1             [서울 가산디지털역] 전문연구요원 어플리케이션 및 클라우드 개발자모집     (주)파이오링크 부설연구소
# 1   2                     (주)바스젠바이오 전임상 연구관리 프로젝트 매니저 채용  (주)바스젠바이오 기업부설연구소
# 2   3  ★[전남,순천] 전문연구요원 모집(보충역가능) - 정밀화학분야★ (이력서제출:kji...    케이에스광학(주) 부설연구소
# 3   4  ★[전남,순천] 전문연구요원 모집(보충역가능) - 정밀화학분야★ (이력서제출:kji...    케이에스광학(주) 부설연구소
# 4   5                        전남대학교 생체재료개발센터 전문연구요원 채용 공고     전남대학교 생체재료개발센터
#
#           마감일         작성일   조회수  \
# 0  2025-04-30  2025-03-06  1898
# 1  2025-05-24  2025-04-24    91
# 2  2025-06-23  2025-04-24    68
# 3  2025-06-09  2025-04-24    55
# 4  2025-05-23  2025-04-24    54
#
#                                             상세정보_URL
# 0  https://work.mma.go.kr/caisBYIS/search/cygongg...
# 1  https://work.mma.go.kr/caisBYIS/search/cygongg...
# 2  https://work.mma.go.kr/caisBYIS/search/cygongg...
# 3  https://work.mma.go.kr/caisBYIS/search/cygongg...
# 4  https://work.mma.go.kr/caisBYIS/search/cygongg...
#                                             상세정보_URL                업체명  \
# 0  https://work.mma.go.kr/caisBYIS/search/cygongg...     (주)파이오링크 부설연구소
# 1  https://work.mma.go.kr/caisBYIS/search/cygongg...  (주)바스젠바이오 기업부설연구소
# 2  https://work.mma.go.kr/caisBYIS/search/cygongg...    케이에스광학(주) 부설연구소
# 3  https://work.mma.go.kr/caisBYIS/search/cygongg...    케이에스광학(주) 부설연구소
# 4  https://work.mma.go.kr/caisBYIS/search/cygongg...     전남대학교 생체재료개발센터
#
#             업종                                                 주소  \
# 0    중소기업부설연구소  서울특별시 금천구 가산디지털2로98 1동 401~403호, 410호, 412~413...
# 1    벤처기업부설연구소  서울특별시 마포구 마포대로109 19층 오(101동)-1901호 (공덕동, 롯데캐슬...
# 2    중소기업부설연구소                         전라남도 순천시 해룡면 율촌산단4로 26-108
# 3    중소기업부설연구소                         전라남도 순천시 해룡면 율촌산단4로 26-108
# 4  자연계대학부설연구기관                                     광주광역시 북구 용봉로77
#
#                       홈페이지 요원형태   자격요원   최종학력  \
# 0      www.piolink.com/kr/   현역  신입/경력  석사 이상
# 1            basgenbio.com   현역  신입/경력  석사 이상
# 2  http://ksoptical.co.kr/   현역  신입/경력  석사 이상
# 3  http://ksoptical.co.kr/   현역  신입/경력  석사 이상
# 4        http://bmccro.com  보충역  신입/경력  석사 이상
#
#                                                 담당업무 근무형태     특근·잔업    수습기간  \
# 0                                   어플리케이션 및 클라우드 개발  주5일        없음  3개월 미만
# 1  세포 및 동물 모델을 활용한 약물 효능 및 기전 평가 관리, 전임상 연구 산출물 관리 등  주5일        없음  3개월 이상
# 2       정밀화학분야 연구개발(광학렌즈 원료 외 기능성 모노머) / 유기합성 / 연구기획  주5일  업체사정에 따름  3개월 미만
# 3       정밀화학분야 연구개발(광학렌즈 원료 외 기능성 모노머) / 유기합성 / 연구기획  주5일  업체사정에 따름  3개월 미만
# 4  의료기기 등 의료제품 비임상시험 수행 및 결과보고서 작성,국가연구개발사업 및 기업지...  주5일        없음  3개월 미만
#
#       퇴직금지급 현역배정인원 보충역배정인원 모집인원    외국어  \
# 0  업체사정에 따름   582명   9999명   1명    NaN
# 1       퇴직금   582명   9999명   1명  영어(중)
# 2       퇴직금     3명    372명   2명    NaN
# 3       퇴직금     3명    372명   2명    NaN
# 4       퇴직금     0명    372명   1명  영어(중)
#
#                                       복리후생  \
# 0  연차, 인센티브제도, 정기보너스, 향후정직원, 건강검진, 본인의료비지원
# 1                      연차, 월차, 정기휴가, 향후정직원
# 2                     연차, 월차, 정기휴가, 통근버스운영
# 3                     연차, 월차, 정기휴가, 통근버스운영
# 4                                   연차, 월차
#
#                                                   비고
# 0  안녕하세요, 채용담당자입니다.\n\n임직원 : 410명\n2024년 전문연구요원 전...
# 1  ○담당업무\nㆍ세포 및 동물 모델을 활용한 약물 효능 및 기전 평가 관리\nㆍ전임상...
# 2  ◆ 전공 : 자연과학계, 공학계\n◆ 우대사항 - 유기합성 전공이 아니더라도 유기합...
# 3  ◆ 전공 : 자연과학계, 공학계\n◆ 우대사항 - 유기합성 전공이 아니더라도 유기합...
# 4                     지원서류 등 별도 양식이 있으니 사전 연락 부탁합니다.
# 기본정보 데이터 개수: (78, 7)
# 상세정보 데이터 개수: (78, 19)

# %%
# 병합 가능한 키 컬럼 확인
common_cols = set(basic_df.columns).intersection(detail_df.columns)
print("공통 컬럼:", common_cols)

# 상세 URL을 기준으로 병합 가능성 판단
merged_df = pd.merge(basic_df, detail_df, on="상세정보_URL", how="inner")
print("병합된 행 개수:", merged_df.shape[0])
# Out:
# 공통 컬럼: {'업체명', '상세정보_URL'}
# 병합된 행 개수: 78

# %%
# 각 컬럼 데이터 타입 및 결측값 비율 확인
print("📑 basic_df info:")
print(basic_df.info())
print(basic_df.isnull().sum())

print("\n📑 detail_df info:")
print(detail_df.info())
print(detail_df.isnull().sum())
# Out:
# 📑 basic_df info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   번호        78 non-null     int64
#  1   채용제목      78 non-null     object
#  2   업체명       78 non-null     object
#  3   마감일       78 non-null     object
#  4   작성일       78 non-null     object
#  5   조회수       78 non-null     int64
#  6   상세정보_URL  78 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 4.4+ KB
# None
# 번호          0
# 채용제목        0
# 업체명         0
# 마감일         0
# 작성일         0
# 조회수         0
# 상세정보_URL    0
# dtype: int64
#
# 📑 detail_df info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상세정보_URL  78 non-null     object
#  1   업체명       78 non-null     object
#  2   업종        78 non-null     object
#  3   주소        78 non-null     object
#  4   홈페이지      72 non-null     object
#  5   요원형태      78 non-null     object
#  6   자격요원      78 non-null     object
#  7   최종학력      78 non-null     object
#  8   담당업무      78 non-null     object
#  9   근무형태      78 non-null     object
#  10  특근·잔업     78 non-null     object
#  11  수습기간      78 non-null     object
#  12  퇴직금지급     78 non-null     object
#  13  현역배정인원    78 non-null     object
#  14  보충역배정인원   78 non-null     object
#  15  모집인원      78 non-null     object
#  16  외국어       18 non-null     object
#  17  복리후생      70 non-null     object
#  18  비고        75 non-null     object
# dtypes: object(19)
# memory usage: 11.7+ KB
# None
# 상세정보_URL     0
# 업체명          0
# 업종           0
# 주소           0
# 홈페이지         6
# 요원형태         0
# 자격요원         0
# 최종학력         0
# 담당업무         0
# 근무형태         0
# 특근·잔업        0
# 수습기간         0
# 퇴직금지급        0
# 현역배정인원       0
# 보충역배정인원      0
# 모집인원         0
# 외국어         60
# 복리후생         8
# 비고           3
# dtype: int64

# %%
def print_unique_values(df, column_name):
    """
    특정 컬럼에서 중복을 제거한 고유값을 모두 출력하는 함수
    """
    if column_name not in df.columns:
        print(f"[오류] '{column_name}' 컬럼은 데이터프레임에 존재하지 않습니다.")
        return

    unique_vals = df[column_name].dropna().unique()
    print(f"\n📦 '{column_name}' 컬럼의 고유값 목록 ({len(unique_vals)}개):")
    for val in unique_vals:
        print("-", val)

# print_unique_values(merged_df, "요원형태")
# print_unique_values(merged_df, "자격요원")
# print_unique_values(merged_df, "최종학력")
# print_unique_values(merged_df, "업종")
print_unique_values(merged_df, "수습기간")
# Out:
# 📦 '수습기간' 컬럼의 고유값 목록 (4개):
# - 3개월 미만
# - 3개월 이상
# - 1개월 미만
# - 2개월 미만
