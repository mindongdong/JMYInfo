# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# 한글 폰트 설정
plt.rcParams['font.family'] = 'AppleGothic'  # macOS의 경우
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
# 데이터 로드
df = pd.read_csv('processed_job_data.csv')

# 데이터 기본 정보 확인
print("데이터 크기:", df.shape)
print("\n컬럼 목록:")
print(df.columns.tolist())
print("\n데이터 타입:")
print(df.dtypes)
# Out:
# 데이터 크기: (115, 12)
#
# 컬럼 목록:
# ['company_name', 'post_name', 'registration_date', 'deadline', 'qualification_agent', 'qualification_education', 'qualification_career', 'region', 'Field', 'keywords_list', 'source_info', 'source_type']
#
# 데이터 타입:
# company_name               object
# post_name                  object
# registration_date          object
# deadline                   object
# qualification_agent        object
# qualification_education    object
# qualification_career       object
# region                     object
# Field                      object
# keywords_list              object
# source_info                object
# source_type                object
# dtype: object

# %%
# 출처별 데이터 수 확인
source_counts = df['source_type'].value_counts()
print("출처별 데이터 수:")
print(source_counts)

# 시각화
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='source_type')
plt.title('출처별 채용 공고 수')
plt.show()
# Out:
# 출처별 데이터 수:
# source_type
# military    74
# rndjob      41
# Name: count, dtype: int64

# %%
# 각 컬럼별 고유값 수 확인
print("각 컬럼별 고유값 수:")
for col in df.columns:
    unique_count = df[col].nunique()
    print(f"{col}: {unique_count}개")
# Out:
# 각 컬럼별 고유값 수:
# company_name: 71개
# post_name: 110개
# registration_date: 57개
# deadline: 30개
# qualification_agent: 3개
# qualification_education: 9개
# qualification_career: 6개
# region: 51개
# Field: 92개
# keywords_list: 100개
# source_info: 115개
# source_type: 2개

# %%
# 날짜 형식 변환
df['registration_date'] = pd.to_datetime(df['registration_date'])
df['deadline'] = pd.to_datetime(df['deadline'])

# 등록일 기준 월별 채용 공고 수
monthly_posts = df.groupby(df['registration_date'].dt.strftime('%Y-%m'))['source_type'].count()

plt.figure(figsize=(12, 6))
monthly_posts.plot(kind='bar')
plt.title('월별 채용 공고 수')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 날짜 형식 변환
# ----> 2 df['registration_date'] = pd.to_datetime(df['registration_date'])
#       3 df['deadline'] = pd.to_datetime(df['deadline'])
#       5 # 등록일 기준 월별 채용 공고 수
#
# File ~/miniconda3/envs/crawl/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/miniconda3/envs/crawl/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~/miniconda3/envs/crawl/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "2025.05.12" doesn't match format "%Y-%m-%d", at position 74. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# 지역별 채용 공고 수
region_counts = df['region'].value_counts().head(10)

plt.figure(figsize=(12, 6))
region_counts.plot(kind='bar')
plt.title('지역별 채용 공고 수 (상위 10개)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 키워드 리스트를 문자열로 변환하고 분리
all_keywords = []
for keywords in df['keywords_list']:
    if isinstance(keywords, list):
        all_keywords.extend(keywords)
    elif isinstance(keywords, str):
        all_keywords.extend(eval(keywords))

# 키워드 빈도수 계산
keyword_counts = pd.Series(all_keywords).value_counts().head(20)

plt.figure(figsize=(12, 6))
keyword_counts.plot(kind='bar')
plt.title('상위 20개 키워드 빈도')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/envs/crawl/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3579 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 7
#     all_keywords.extend(eval(keywords))
#
#   File <string>:8
#     ㆍ경력 : 경력 2년 ~ 8년(선임연구원, 주임연구원급, 면접 후 결정)
#              ^
# SyntaxError: invalid decimal literal

# %%
# 각 출처별 샘플 데이터 확인
print("Military 데이터 샘플:")
print(df[df['source_type'] == 'military'].head())
print("\nRND Job 데이터 샘플:")
print(df[df['source_type'] == 'rndjob'].head())
# Out:
# Military 데이터 샘플:
#        company_name                              post_name registration_date  \
# 0     실리콘디스플레이기흥연구소                               설계연구원 모집        2025-04-22
# 1   (주)케이넷츠 기업부설연구소         이동통신용 중계기 시스템 및 HW 엔지니어 경력직 채용        2025-04-22
# 2  (주)디노티시아 기업부설연구소                      [디노티시아] 전문연구요원 채용        2025-04-09
# 3     (주)메리테크 부설연구소  (주)메리테크 R&D센터 기구설계 전문연구요원(병역특례) 인력 채용        2025-04-21
# 4  (주)호진플라텍부설 기술연구소                        기술연구소 전문연구요원 채용        2024-02-01
#
#      deadline qualification_agent qualification_education  \
# 0  2025-05-31                  기타                   석사 이상
# 1  2025-05-30                 보충역          대학 졸업(2,3년) 이상
# 2  2025-05-31                  현역                   석사 이상
# 3  2025-06-17                  현역                   석사 이상
# 4  2025-06-12                  현역                   석사 이상
#
#   qualification_career                                       region  \
# 0            경력 (3년이상)  경기도 용인시 기흥구 탑실로58번길 8 - 0 3층(실리콘디스플레이 ,공세동)
# 1                신입/경력   서울특별시 금천구 가산디지털2로123 1510호 (가산동, 월드메르디앙2차)
# 2                신입/경력             서울특별시 강남구 강남대로318 13층, 14층 (역삼동)
# 3                신입/경력            경기도 화성시 동탄첨단산업1로 28, 3층, 4층 (영천동)
# 4                신입/경력                경기도 안산시 단원구 목내로119번길 91 (목내동)
#
#                                                Field  \
# 0                  TFT 소자/패널 설계, 이미지 센서 개발, 디스플레이 개발
# 1                이동통신용 중계기 개발 / DAS 개발 / 대드론 Jmmer개발
# 2  SoC Design / RTL Design / DV / Machine Learnin...
# 3  기구설계 및 열, 유체 Simulation software 사용한 최적의 기구설계 ...
# 4                                               연구개발
#
#                                        keywords_list  \
# 0                                                NaN
# 1  주요업무\nㆍ 이동통신용 중계기 개발 / DAS 개발 / 대드론 Jmmer개발\nㆍ...
# 2                                                NaN
# 3  [담당업무]\n- 기구설계 및 열, 유체 Simulation software 사용한...
# 4  1. 당사 수습기간은 없습니다. 대신, 기간제근로계약 3개월 근무 후 재계약합니다....
#
#                                          source_info source_type
# 0  https://work.mma.go.kr/caisBYIS/search/cygongg...    military
# 1  https://work.mma.go.kr/caisBYIS/search/cygongg...    military
# 2  https://work.mma.go.kr/caisBYIS/search/cygongg...    military
# 3  https://work.mma.go.kr/caisBYIS/search/cygongg...    military
# 4  https://work.mma.go.kr/caisBYIS/search/cygongg...    military
#
# RND Job 데이터 샘플:
#    company_name                                   post_name registration_date  \
# 74    (주)에임드바이오  병역특례 전문요원 모집(의학, BIO 및 IT분야)_2025년은 전직만 가능        2025.05.12
# 75      (주)지크립토                          DevOps Engineer 채용        2025.05.09
# 76      (주)지크립토              Front-end Engineer (junior) 채용        2025.05.09
# 77      (주)지크립토               Back-end Engineer (junior) 채용        2025.05.09
# 78           급구                     AI데이터 분석 연구원 채용(전직자 우대)        2025.05.09
#
#       deadline qualification_agent qualification_education  \
# 74  2025.05.31                 NaN             석사졸업 예정자 이상
# 75  2025.06.30                 NaN                     NaN
# 76  2025.06.30                 NaN                     NaN
# 77  2025.06.30                 NaN                     NaN
# 78  2025.05.23                 NaN                     NaN
#
#    qualification_career region  \
# 74                신입/경력    NaN
# 75                   무관    NaN
# 76                   무관    NaN
# 77                   무관    NaN
# 78                   경력    NaN
#
#                                                 Field  \
# 74  ['연구개발 > 바이오/제약/식품 > 바이오,\xa0의약,\xa0제약', '2명 모집']
# 75  ['IT/정보통신 > 시스템/보안 > 방화벽,\xa0Linux,\xa0서버관리', ...
# 76   ['IT/정보통신 > 응용프로그래머 > Android,\xa0IOS', '0명 모집']
# 77                   ['IT/정보통신 > 응용프로그래머 >', '0명 모집']
# 78  ['연구개발 > 기타 연구개발/기술/생산 > 기타 연구개발/기술/생산', '0명 모집']
#
#                                         keywords_list  \
# 74  ['(주)에임드바이오는 항암신약개발 및 정밀의료 전문 바이오기업입니다.[모집분야] ...
# 75  ['ㆍEKS 기반 서비스 인프라 운영 및 최적화ㆍIaC 기반 클러스터 구성 및 관리...
# 76  ['ㆍ지크립토의 블록체인, 영지식 증명을 이용한 서비스들의 프론트엔드 개발ㆍ서비스들...
# 77  ['ㆍ 지크립토의 블록체인 영지식증명을 이용한 서비스들의 백엔드 개발ㆍ 공통으로 사...
# 78  ['AI·LLM·공간데이터 분석 기업공간 데이터 기반 모델링 / 분석Python 기...
#
#                                           source_info source_type
# 74  https://www.rndjob.or.kr/info/sp_eview01.asp?g...      rndjob
# 75  https://www.rndjob.or.kr/info/sp_eview01.asp?g...      rndjob
# 76  https://www.rndjob.or.kr/info/sp_eview01.asp?g...      rndjob
# 77  https://www.rndjob.or.kr/info/sp_eview01.asp?g...      rndjob
# 78  https://www.rndjob.or.kr/info/sp_eview01.asp?g...      rndjob
